# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
reg = LinearRegression()
log = LogisticRegression()

X = [[1], [-43], [3], [-10], [0.01], [0.3] ]
Y = [-3,   108,  -10,   32,   0.76,   -1]
y = [ 0,    0,    1,    1,    0,       0]

reg.fit(X, Y)
log.fit(np.column_stack([X,Y]), y)
# Out:
# LogisticRegression()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
_X = np.column_stack([X, Y])
# Out:
# array([[ 1.00e+00, -3.00e+00],
#        [-4.30e+01,  1.08e+02],
#        [ 3.00e+00, -1.00e+01],
#        [-1.00e+01,  3.20e+01],
#        [ 1.00e-02,  7.60e-01],
#        [ 3.00e-01, -1.00e+00]])

# %%
plt.scatter(X, Y)
x = np.linspace(-50, 5, 200)
y = -2.54 * x + 0.5346
plt.plot(x, y, c='red')

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(projection='3d')
ax.scatter(X, Y)
x, y = np.linspace(-50, 5, 200), np.linspace(-10, 130, 400)
x_plane, y_plane = np.meshgrid(x, y)
z = x_plane * 0.48 + y_plane * 0.17 + (-0.59)
ax.plot(x_plane, y_plane, z, alpha=0.4)
